# %%
import numpy as np

# %%
np.random.rand(5)
# Out:
# array([0.79601231, 0.82643078, 0.03902196, 0.20374081, 0.11756947])

# %%
np.random.rand(2,4)
# Out:
# array([[0.23625628, 0.30665067, 0.76036546, 0.54807881],
#        [0.46810074, 0.87111748, 0.15556643, 0.33589453]])

# %%
np.random.randint(20,100,size = 10)
# Out:
# array([62, 64, 97, 91, 68, 22, 24, 38, 68, 71], dtype=int32)

# %%
np.random.randint(20,50, size = (3,3))
# Out:
# array([[25, 26, 31],
#        [35, 41, 29],
#        [20, 47, 22]], dtype=int32)

# %%
np.random.choice([1,2,3,4,5],size = 3,replace = False )
# Out:
# array([3, 4, 5])

# %%
colors = ['green', 'grey', 'orange']
probabilities = [0.1, 0.3, 0.6]  # green is most likely

picked = np.random.choice(colors, size=10, p=probabilities)
print(picked)
# Out:
# ['grey' 'orange' 'orange' 'grey' 'grey' 'orange' 'orange' 'orange'
#  'orange' 'grey']

# %%
a = np.array([12,34,22,123])
np.random.choice(a,size = 2,replace = False)
# Out:
# array([ 12, 123])

# %%
np.random.normal(0,5,size = 4)
# Out:
# array([ 2.60748735, -2.22925904,  9.71252712,  7.02962723])

# %%
ab = np.array([11,22,34,12,123,23])
np.random.shuffle(ab)
print(ab)
# Out:
# [ 34  12  23  11 123  22]

# %%
np.random.uniform(10, 20, size=5)
# Out:
# array([12.29577214, 15.34413909, 19.13962025, 14.57204808, 14.30698567])

# %%
np.random.uniform(-5, 5, size=(2, 3))
# Out:
# array([[ 4.39127789,  2.78389236,  2.15970516],
#        [ 3.02757504, -4.07199191,  0.18152549]])

# %%
outcomes = ['HEADS','TRIALS']
PROBABILITIES = [0.5,0.5]
b = np.random.choice(outcomes,size = 10,p = PROBABILITIES)
print(b)
# Out:
# ['HEADS' 'TRIALS' 'TRIALS' 'TRIALS' 'TRIALS' 'HEADS' 'HEADS' 'HEADS'
#  'HEADS' 'TRIALS']

# %%
np.random.seed(21)
print(np.random.randint(1, 10, 3))
# Out:
# [9 5 1]
