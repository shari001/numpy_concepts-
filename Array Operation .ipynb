# %%
import numpy as np

# %%
ar1 = np.array([1,2,21,34])
ar2 = np.array([2,4,2,12])

# %% [markdown]
#                             # Athermatic operation

# %%
ar1 + ar2
# Out:
# array([ 3,  6, 23, 46])

# %%
ar1 ** ar2
# Out:
# array([                  1,                  16,                 441,
#        2386420683693101056])

# %%
ar1 - ar2
# Out:
# array([-1, -2, 19, 22])

# %%
ar1 * ar2
# Out:
# array([  2,   8,  42, 408])

# %%
ar1 / ar2
# Out:
# array([ 0.5       ,  0.5       , 10.5       ,  2.83333333])

# %%
a = np.array([[1,2,3],
            [1,4,67],
            [32,1,23]])

# %%
np.sum(a)
# Out:
# np.int64(134)

# %%
np.max(a)
# Out:
# np.int64(67)

# %%
np.min(a)
# Out:
# np.int64(1)

# %%
np.mean(a)
# Out:
# np.float64(14.88888888888889)

# %%
np.std(a)
# Out:
# np.float64(21.288726512950696)

# %%
ar3 = np.array([[1,2],[3,5]])
ar4 = np.array([[2,5]])
ar5 = np.array([[3,7]])
arr_1 = np.vstack((ar3,ar4,ar5))

# %%
arr_1
# Out:
# array([[1, 2],
#        [3, 5],
#        [2, 5],
#        [3, 7]])

# %%
st1 = np.array([[1,2],[4,5]])
st2 = np.array([[7,9],[6,4]])
arr_2 = np.hstack((st1,st2))

# %%
arr_2
# Out:
# array([[1, 2, 7, 9],
#        [4, 5, 6, 4]])

# %%
li_1 = np.arange(9)
np.split(li_1,3)
# Out:
# [array([0, 1, 2]), array([3, 4, 5]), array([6, 7, 8])]

# %%
arr = np.array([[1,23,445],
                [33,17,5]])

# %%
np.var(arr)
# Out:
# np.float64(25699.22222222223)

# %%
np.percentile(arr,100)
# Out:
# np.float64(445.0)

# %%
np.sum(arr,axis = 0)
# Out:
# array([ 34,  40, 450])

# %%
np.sum(arr,axis = 1)
# Out:
# array([469,  55])

# %%
data = np.array([10,20,30,40,50])

# %%
value = data>25
print(value)
print(data[value])
# Out:
# [False False  True  True  True]
# [30 40 50]

# %%
value1 = (data > 25) & (data < 40)

# %%
(data[value1])
# Out:
# array([30])

# %%
marks = np.array([87,44,32,69,65,32])

# %%
marks + 5
# Out:
# array([92, 49, 37, 74, 70, 37])

# %%
np.where(data>25, data + 5,data)
# Out:
# array([10, 20, 35, 45, 55])

# %%
a = np.array([[1,2],
             [2,4]])

b = np.array([[4,5],
              [3,2]])

# %%
np.dot(a,b)
# Out:
# array([[10,  9],
#        [20, 18]])

# %% [markdown]
#                                  #Inverse matrix
#                                  ##Formula
#                                  A^-1 = 1
#                                        ____  =    [d -b]
#                                        ad-bc      [-c a]

# %%
inv_det = ([[4,1],
           [4,2]])

# %%
np.linalg.inv(inv_det)
# Out:
# array([[ 0.5 , -0.25],
#        [-1.  ,  1.  ]])

# %%
np.linalg.det(inv_det)
# Out:
# np.float64(4.0)

# %% [markdown]
# 5x + 3y = 4
# 4x + 2y = 1
# a = [5 3]
#     [4,2]
#
# b = [4]
#     [1]
#
# x =  [x]
#      [y]

# %%
x = np.array([[5,3],
             [4,2]])
y = np.array([4,1])
np.linalg.solve(x,y)
# Out:
# array([-2.5,  5.5])

# %%
np.load('data.npy')
# Out:
# array([10, 12, 15])
