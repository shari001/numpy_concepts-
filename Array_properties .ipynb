# %%
import numpy as np

# %%
a = np.array([[[1,23,34]])
a.size
print(a.shape)
print(a.ndim)
print(a.dtype)
# Out:
# (1, 1, 3)
# 3
# int64

# %%
b = np.array([
    [12,34,545,345],
    [232,344,23,3],
    [123,43,221,34],
    [12,34,545,234],
    [232,344,23,23],
    [123,43,221,43],
    [12,34,545,44],
    [232,344,23,43],
    [123,43,221,54],
    [12,34,545,432],
    [232,344,23,45],
    [123,43,221,65]
])
print(b.size)
print(b.shape)
print(b.ndim)
print(b.dtype)
# Out:
# 48
# (12, 4)
# 2
# int64
